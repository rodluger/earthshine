# %%
# %matplotlib inline
import starry_beta
import numpy as np

# %%
map = starry_beta.Map(25)

# %%
map.load_image("/Users/rluger/Desktop/earth_super_hack.jpg")

# %%
yearth = np.array(map.y)

# %%
map.animate()
# Out:
# <img src="90776496896.gif">

# %%
import starry

# %%
map = starry.Map(25)
map[:, :] = yearth

# %%
map.show(projection="rect")

# %%
import matplotlib.pyplot as plt

# %%
power = [np.sum(map[l, :] ** 2) for l in range(map.ydeg + 1)]

# %%
def std(l, a=4.25, b=0.7, c=0.01):
    if l == 0:
        return 1
    elif l < a:
        return c * l ** b
    else:
        return c * a ** (2 * b) * l ** -b

plt.plot(ls, [np.std(map[l, :]) for l in ls])
plt.plot(ls, [std(l) for l in ls])
plt.yscale("log")
